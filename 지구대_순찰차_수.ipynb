# %% [markdown]
# <a href="https://colab.research.google.com/github/seon0415/weit/blob/main/%EC%A7%80%EA%B5%AC%EB%8C%80_%EC%88%9C%EC%B0%B0%EC%B0%A8_%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc('font', family='Malgun Gothic')

car=pd.read_csv("경찰청 서울특별시경찰청_경찰서별 112 순찰차 현황_20211231.csv", encoding='CP949')
police=pd.read_csv("경찰청 서울특별시경찰청_경찰서별 지역경찰 현황_20211231.csv", encoding='CP949')
office=pd.read_csv("시내주요기관(경찰·소방관서)_20230317212437.csv")

# %%
car['경찰서']=car['경찰서'].str.replace(" ","")

# %%
df=pd.merge(car,police,on='경찰서').drop(columns='순번').set_index('경찰서')
df['2018년_지역경찰']=df['2018년 지구대']+df['2018년 파출소']+df['2018년 치안센터']
df['2019년_지역경찰']=df['2019년 지구대']+df['2019년 파출소']+df['2019년 치안센터']
df['2020년_지역경찰']=df['2020년 지구대']+df['2020년 파출소']+df['2020년 치안센터']
df['2021년_지역경찰']=df['2021년 지구대']+df['2021년 파출소']+df['2021년 치안센터']
df.rename(columns={'대수':'2021년_순찰차'}, inplace=True)
df.drop(columns=df.iloc[:,1:13])
# Out:
#      2021년_순찰차  2018년_지역경찰  2019년_지역경찰  2020년_지역경찰  2021년_지역경찰
# 경찰서
# 중부          17          11          11          10          10
# 종로          19          14          14          14          14
# 남대문         12           7           7           7           7
# 서대문         25          11          11          10          10
# 혜화          14           9           9           9           9
# 용산          25          12          12          12          12
# 성북          17          14          14          14          14
# 동대문         31          20          20          20          20
# 마포          31          17          15          15          15
# 영등포         32          15          15          15          15
# 성동          22          15          15          15          15
# 동작          25          17          17          17          17
# 광진          28          12          12          12          12
# 서부          15           8           8           8          10
# ...

# %%
office.columns
# Out:
# Index(['자치구별(1)', '자치구별(2)', '1988', '1988.1', '1988.2', '1988.3', '1989',
#        '1989.1', '1989.2', '1989.3',
#        ...
#        '2020.2', '2020.3', '2020.4', '2020.5', '2021', '2021.1', '2021.2',
#        '2021.3', '2021.4', '2021.5'],
#       dtype='object', length=190)

# %%
office=pd.read_csv("시내주요기관(경찰·소방관서)_20230317212437.csv")
office=office.drop(columns='자치구별(1)').drop(index=0).rename(columns={'자치구별(2)':'경찰서'})
office['경찰서']=office['경찰서'].str.replace("구","")
office.set_index('경찰서')
# Out:
#     1988 1988.1 1988.2 1988.3 1989 1989.1 1989.2 1989.3 1990 1990.1  ...  \
# 경찰서                                                                  ...
# 소계    25    567     13     71   25    574     14     77   27    589  ...
# 종로     2     40      1      4    2     40      1      5    2     40  ...
# 중      2     43      1      3    2     43      1      3    2     43  ...
# 용산     1     29      1      4    1     29      1      4    1     29  ...
# 성동     2     41      1      5    2     41      1      5    2     41  ...
# 광진     -      -      -      -    -      -      -      -    -      -  ...
# 동대문    1     34      1      3    1     34      1      3    1     34  ...
# 중랑     1     17      -      3    1     17      -      3    1     17  ...
# 성북     2     37      1      4    2     37      1      4    2     37  ...
# 강북     -      -      -      -    -      -      -      -    -      -  ...
# 도봉     1     31      -      3    1     31      1      4    1     32  ...
# ...

# %%
import folium
import json

folium.Map(location=[35.95, 127.7],   #지도중심좌표
           zoom_start=8 )             #확대단계

map_sig=folium.Map(location=[35.95, 127.7],
                   zoom_start=8)  #지도종류

folium.Choropleth(
    geo_data=df,
    data=df,
    columns=('code','pop'),
    key_on='feature.properties.ADM_DR_CD',
    fill_color='Blues',
    nan_fill_color='White',
    fill_opacity=1,
    line_opacity=0.5,
    bins=bins)\
    .add_to(map_seoul)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-117-8d390ac1078b> in <module>
#      10 folium.Choropleth(
#      11     geo_data=df,
# ---> 12     data=foreigner,
#      13     columns=('code','pop'),
#      14     key_on='feature.properties.ADM_DR_CD',
#
# NameError: name 'foreigner' is not defined

# %% [markdown]
# 히트맵 상관관계 분석

# %%
office.transpose().set_index('경찰서')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-3260c39a149e> in <module>
# ----> 1 office.transpose().set_column('경찰서')
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'set_column'

# %%
for k in range(1,183):
  office[k]=office.iloc[:,[k]]+office.iloc[:,[k+1]]+office.iloc[:,[k+2]]+office.iloc[:,[k+3]]+office.iloc[:,[k+4]]
  k=``

# %%
office.iloc[:,[183]]
